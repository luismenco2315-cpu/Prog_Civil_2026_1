# %% [markdown]
# <a href="https://colab.research.google.com/github/luismenco2315-cpu/Prog_Civil_2026_1/blob/main/Notebook_semana_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# ENTRADAS:ancho y alto en metros
ancho = input("ingrese ancho de la ventana en metros")
ancho = float(ancho)
alto = input("ingrese el alto de la ventana en metros")
alto = float(alto)
# PROCESO: Calcula lm en pies y av en metros cuadrados
lm = 2 * (ancho + alto) * 3.25
av = (ancho * alto) * 2
#SALIDA: Sale la longitud de la madera (lm) en pies y área del vidrio en metroos cuadrados
print("longitud de la madera = ",lm,"pies de longitud")
print("área de la ventana = ",av, "Metros cuadrados")
# Out:
# ingrese ancho de la ventana en metros1
# ingrese el alto de la ventana en metros2
# longitud de la madera =  19.5 pies de longitud
# área de la ventana =  4.0 Metros cuadrados

# %%
import this

# %%
import this
